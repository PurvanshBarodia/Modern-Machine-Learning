# %% [markdown]
# <a href="https://colab.research.google.com/github/PurvanshBarodia/Modern-Machine-Learning/blob/main/Module%208/FMML20210266_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-12 19:26:35--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   167MB/s    in 0.4s
#
# 2022-06-12 19:26:39 (167 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39519  1607.08236v1  As an alternative to conventional multi-pixel ...    cs
# 5570    1303.0642v2  As an alternative to variable selection or shr...  stat
# 39460  1605.07264v1  This paper presents the probability hypothesis...  stat
# 12528  1802.07513v1  Classification problems in security settings a...  stat
# 24337   1310.1771v1  The problem of minimizing the Potts energy fun...    cs
# ...             ...                                                ...   ...
# 20589  1607.05906v1  Purpose: To develop a framework for identifyin...    cs
# 6455   1702.04121v1  Over the past decade there has been considerab...  stat
# 39081   1211.7102v1  Singular Value Decomposition (SVD) has recentl...    cs
# 19019   1301.6742v1  The noisy-or and its generalization noisy-max ...    cs
# 10077  1703.02702v1  Deep neural networks coupled with fast simulat...    cs
#
#                                                    title  year  \
# 39519  Adaptive foveated single-pixel imaging with dy...  2016
# 5570                      Bayesian Compressed Regression  2013
# 39460   Trajectory probability hypothesis density filter  2016
# 12528  Adversarial classification: An adversarial ris...  2018
# 24337  Potts model, parametric maxflow and k-submodul...  2013
# ...                                                  ...   ...
# 20589  Refining adverse drug reaction signals by inco...  2016
# 6455   Practical Learning of Predictive State Represe...  2017
# 39081  SVD Based Image Processing Applications: State...  2012
# 19019          Multiplicative Factorization of Noisy-Max  2013
# 10077          Robust Adversarial Reinforcement Learning  2017
#
#                                                 keywords
# 39519  [alternative, conventional, correlations, corr...
# 5570   [alternative, selection, shrinkage, dimensiona...
# 39460  [probability, hypothesis, trajectories, result...
# 12528  [classification, contemplated, confrontations,...
# 24337  [minimizing, frequently, applications, identif...
# ...                                                  ...
# 20589  [framework, identifying, incorporating, candid...
# 6455   [considerable, algorithms, predictive, represe...
# 39081  [decomposition, processing, different, attract...
# 19019  [generalization, complexity, knowledge, acquis...
# 10077  [simulation, computation, successes, reinforce...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39519    [alternative, conventional, correlations, corr...
# 5570     [alternative, selection, shrinkage, dimensiona...
# 39460    [probability, hypothesis, trajectories, result...
# 12528    [classification, contemplated, confrontations,...
# 24337    [minimizing, frequently, applications, identif...
#                                ...
# 1621     [recognition, combining, convolutional, transc...
# 6248     [adaptation, important, occurring, distributio...
# 22244    [mnkclassical, controller, activating, sequent...
# 27863    [pollutant, emissions, regaining, popularity, ...
# 12930    [participation, communities, intertwinement, s...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8815 words.
# Out of those 4576 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="883bd27e-6390-4b62-bef5-9fced5a8331e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("883bd27e-6390-4b62-bef5-9fced5a8331e")) {                    Plotly.newPlot(                        "883bd27e-6390-4b62-bef5-9fced5a8331e",                        [{"x":["approaches","techniques","knowledge","therefore","typically","sequential","technique","reduction","reconstructed","dynamically","reconstruct","conventional","framework","described","computational","compressive","accumulating","simultaneously","correlations","developed","evolution","resolution","information","redundancy","different","consecutive","demonstrate","spatially","complement","correlation","effective","alternative","measurements","reconstruction","robustness","compressed","bypassing","uncertainty","illustrated","averaging","analytically","conditional","predictors","dimensional","convergence","competitors","dramatically","dimension","available","magnitude","asymptotic","selection","practical","parametric","performing","performance","computation","shrinkage","distribution","regression","dimensionality","applications","simulations","bottlenecks","theoretical","predictive","projection","posterior","accommodating","sensitivity","projected","probability","requiring","filtering","measurement","recursively","hypothesis","principled","hypotheses","divergence","resulting","estimating","approximation","trajectory","trajectories","computationally","association","minimising","recursion","obtaining","efficient","implementation","underlying","assumptions","adversaries","adversarial","illustrate","realistic","classification","discussed","classifier","subsequent","relaxations","frequently","generalize","computations","unlabeled","significant","submodular","furthermore","algorithm","functions","connection","expansion","combinatorial","optimization","minimizing","identifies","gradients","prediction","contributions","advantages","traditional","presented","visualizations","introduce","splitting","projections","decompose","validated","subsequently","visualization","adaptiveness","interactions","methodology","dependence","geometrical","interpret","nonetheless","consequence","interpretation","difficult","visualize","structure","visualized","thresholding","amplitude","transform","corresponds","recording","diagnostic","cardiovascular","electrical","examination","measuring","automatic","electrocardiogram","heartbeat","processing","identification","detection","anomalies","concerned","composition","important","condition","determined","similarly","extraction","sensitive","individual","introduces","principle","successful","intuitions","developers","mathematical","perceptron","particular","experience","artificial","recognition","multilayer","connectionist","competition","algorithms","conference","international","documents","recurrent","essentially","historical","comprises","handwritten","intelligent","technologies","extremely","inference","arbitrary","stochastic"],"y":[419,346,352,118,110,83,246,98,29,30,44,100,565,88,303,18,1,110,25,222,56,135,673,17,758,16,546,18,24,67,248,107,49,108,105,22,3,72,23,23,17,98,19,179,143,7,23,62,281,53,17,155,141,50,61,887,136,5,211,125,58,459,38,5,163,63,39,34,1,30,19,147,54,68,25,14,48,17,29,25,153,54,125,22,28,98,20,2,4,38,462,125,114,73,8,107,77,63,486,66,153,30,7,30,68,38,48,252,7,143,833,223,44,18,41,328,42,20,43,224,33,101,191,173,9,344,15,17,11,30,14,35,0,68,73,23,12,28,3,21,67,137,13,318,5,16,3,76,27,16,19,2,7,5,33,194,1,2,292,102,307,12,21,21,361,37,52,14,134,51,111,64,54,77,5,2,68,24,275,41,147,363,15,10,32,585,19,16,62,143,25,24,22,26,65,39,51,230,96,128],"type":"bar"},{"x":["approaches","techniques","knowledge","therefore","typically","sequential","technique","r ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4576,), (4576, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Value</span> <span style=''>Function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximation</span> <span style=''>in</span> <span style=''>Noisy</span> <span style='background-color:rgba(0, 255, 0, 0.47663551401869153);'>Environments</span> <span style=''>Using</span> <span style=''>Locally</span> <span style=''>Smoothed</span> <span style='background-color:rgba(255, 0, 0, 0.4961832061068702);'>Regularized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximate</span> <span style=''>Linear</span> <span style=''>Programs</span> <br/><br/><span style=''>Recently</span> <span style=''>Petrik</span> <span style=''>et</span> <span style=''>al</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>that</span> <span style=''>L1Regularized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximate</span> <span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3828571428571428);'>Programming</span> <span style=''>(RALP)</span> <span style=''>could</span> <span style=''>produce</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>policies</span> <span style=''>which</span> <span style=''>compared</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>favorably</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>established</span> <span style=''>linear</span> <span style=''>value</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>like</span> <span style=''>LSPI</span> <span style=''>RALPs</span> <span style=''>success</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>primarily</span> <span style=''>stems</span> <span style=''>from</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>and</span> <span style=''>value</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>steps</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>RALPs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>become</span> <span style=''>looser</span> <span style=''>if</span> <span style=''>sampled</span> <span style=''>next</span> <span style=''>states</span> <span style=''>are</span> <span style=''>used</span> <span style=''>For</span> <span style=''>very</span> <span style=''>noisy</span> <span style=''>domains</span> <span style=''>RALP</span> <span style=''>requires</span> <span style=''>an</span> <span style=''>accurate</span> <span style=''>model</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>samples</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unrealistic</span> <span style=''>in</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scenarios</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>this</span> <span style=''>weakness</span> <span style=''>and</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>Locally</span> <span style=''>Smoothed</span> <span style=''>L1</span> <span style='backgr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Prior</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Likelihood</span> <span style=''>Choices</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorisation</span> <span style=''>on</span> <span style=''>Small</span> <span style=''>Datasets</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>effects</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>prior</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>choices</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorisation</span> <span style=''>focusing</span> <span style=''>on</span> <span style=''>small</span> <span style=''>datasets</span> <span style=''>These</span> <span style=''>choices</span> <span style=''>can</span> <span style=''>greatly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influence</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>We</span> <span style=''>identify</span> <span style=''>four</span> <span style=''>groups</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>with</span> <span style=''>real</span> <span style=''>valued</span> <span style=''>priors</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonnegative</span> <span style=''>priors</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonnegative</span> <span style=''>models</span> <span style=''>and</span> <span style=''>finally</span> <span style=''>Poisson</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>For</span> <span style=''>each</span> <span style=''>group</span> <span style=''>we</span> <span style=''>review</span> <span style=''>several</span> <span style=''>models</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considering</span> <span style=''>sixteen</span> <span style=''>in</span> <span style=''>total</span> <span style=''>and</span> <span style=''>discuss</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relations</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>priors</span> <span style=''>and</span> <span style=''>matrix</span> <span style=''>norms</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensively</span> <span style=''>compare</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>on</span> <span style=''>eight</span> <span style=''>real</span> <span style=''>world</span> <span style=''>datasets</span> <span style=''>across</span> <span style=''>three</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>areas</span> <span style=''>giving</span> <span style=''>both</span> <span style=''>inter</span> <span style=''>and</span> <span style=''>intra</span> <span style=''>group</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparisons</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>simpler</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>obtaining</span> <span style=''>an</span> <span style=''>O(1t)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projected</span> <span style='background-color:rgba(255, 0, 0, 0.37254901960784326);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666666);'>subgradient</span> <span style=''>method</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>note</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>averaging</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projected</span> <span style='background-color:rgba(255, 0, 0, 0.37254901960784326);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666666);'>subgradient</span> <span style=''>method</span> <span style=''>By</span> <span style=''>using</span> <span style=''>a</span> <span style=''>weighted</span> <span style=''>average</span> <span style=''>with</span> <span style=''>a</span> <span style=''>weight</span> <span style=''>of</span> <span style=''>t1</span> <span style=''>for</span> <span style=''>each</span> <span style=''>iterate</span> <span style=''>w</span> <span style=''>t</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iteration</span> <span style=''>t</span> <span style=''>we</span> <span style=''>obtain</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>of</span> <span style=''>O(1t)</span> <span style=''>with</span> <span style=''>both</span> <span style=''>an</span> <span style=''>easy</span> <span style=''>proof</span> <span style=''>and</span> <span style=''>an</span> <span style=''>easy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementation</span> <span style=''>The</span> <span style=''>new</span> <span style=''>scheme</span> <span style=''>is</span> <span style=''>compared</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirically</span> <span style=''>to</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>with</span> <span style=''>similar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>behavior</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>GPatt</span> <span style=''>Fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multidimensional</span> <span style=''>Pattern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Extrapolation</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothing</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>on</span> <span style=''>small</span> <span style=''>datasets</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>GPatt</span> <span style=''>enabling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style=''>pattern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extrapolation</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>on</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multidimensional</span> <span style=''>datasets</span> <span style=''>GPatt</span> <span style=''>unifies</span> <span style=''>and</span> <span style=''>extends</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressive</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>fast</span> <span style=''>exact</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>Without</span> <span style=''>human</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intervention</span> <span style=''>no</span> <span style=''>hand</span> <span style=''>crafting</span> <span style=''>of</span> <span style=''>kernel</span> <span style=''>features</span> <span style=''>and</span> <span style=''>no</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sophisticated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>initialisation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>GPatt</span> <span style=''>can</span> <span style=''>solve</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>pattern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extrapolation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inpainting</span> <span style=''>and</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovery</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>a</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>383400</span> <span style=''>training</span> <span style=''>points</span> <span style=''>We</span> <span style=''>find</span> <span style=''>that</span> <span style=''>GPatt</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperforms</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>scalable</span> <span style=''>Gaussian</span> <span style=''>process</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10421127765881513)
# 	evaluation (0.0945753033547466)
# 	information (0.24018558172733762)
# 	experimental (0.13276231263383298)
# 	segmentation (0.06745182012847965)
# 	architecture (0.09029264810849394)
# 	detection (0.10956459671663098)
# 	different (0.2705210563882941)
# 	recognition (0.12955032119914348)
# 	convolutional (0.13240542469664526)
#
# Some Statistics words are:
# 	variables (0.13413413413413414)
# 	algorithm (0.38288288288288286)
# 	stochastic (0.14014014014014015)
# 	theoretical (0.15465465465465467)
# 	statistical (0.16366366366366367)
# 	distribution (0.1806806806806807)
# 	estimation (0.1781781781781782)
# 	inference (0.2007007007007007)
# 	dimensional (0.1956956956956957)
# 	regression (0.18118118118118118)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="40836e19-27cf-4760-84fd-9a01825565b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40836e19-27cf-4760-84fd-9a01825565b0")) {                    Plotly.newPlot(                        "40836e19-27cf-4760-84fd-9a01825565b0",                        [{"x":["approaches","techniques","knowledge","therefore","typically","sequential","technique","reduction","reconstructed","dynamically","reconstruct","conventional","framework","described","computational","compressive","accumulating","simultaneously","correlations","developed","evolution","resolution","information","redundancy","different","consecutive","demonstrate","spatially","complement","correlation","effective","alternative","measurements","reconstruction","robustness","compressed","bypassing","uncertainty","illustrated","averaging","analytically","conditional","predictors","dimensional","convergence","competitors","dramatically","dimension","available","magnitude","asymptotic","selection","practical","parametric","performing","performance","computation","shrinkage","distribution","regression","dimensionality","applications","simulations","bottlenecks","theoretical","predictive","projection","posterior","accommodating","sensitivity","projected","probability","requiring","filtering","measurement","recursively","hypothesis","principled","hypotheses","divergence","resulting","estimating","approximation","trajectory","trajectories","computationally","association","minimising","recursion","obtaining","efficient","implementation","underlying","assumptions","adversaries","adversarial","illustrate","realistic","classification","discussed","classifier","subsequent","relaxations","frequently","generalize","computations","unlabeled","significant","submodular","furthermore","algorithm","functions","connection","expansion","combinatorial","optimization","minimizing","identifies","gradients","prediction","contributions","advantages","traditional","presented","visualizations","introduce","splitting","projections","decompose","validated","subsequently","visualization","adaptiveness","interactions","methodology","dependence","geometrical","interpret","nonetheless","consequence","interpretation","difficult","visualize","structure","visualized","thresholding","amplitude","transform","corresponds","recording","diagnostic","cardiovascular","electrical","examination","measuring","automatic","electrocardiogram","heartbeat","processing","identification","detection","anomalies","concerned","composition","important","condition","determined","similarly","extraction","sensitive","individual","introduces","principle","successful","intuitions","developers","mathematical","perceptron","particular","experience","artificial","recognition","multilayer","connectionist","competition","algorithms","conference","international","documents","recurrent","essentially","historical","comprises","handwritten","intelligent","technologies","extremely","inference","arbitrary","stochastic","clustering","likelihood","generating","factorization","mechanism","hierarchical","substantially","explicitly","variational","implement","researches","consideration","plausible","attentions","appearances","characteristics","personalized","exploring","preserving","development","experimental","progression","influences","autoencoder","considerable","generative","facilitate","influence","personality","comparing","functional","laplacian","multiclass","modification","interface","variation","introducing","smoothness","preserves","supervised","motivated","potential","transitions","construct","competitive","numerical","principal","experiments","decomposition","simulated","component","formulations","smoothing","sequentially","observing","eigenvalues","discou ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	adaptiveness
# 	covariances
# 	contiguous
# 	eigendecomposition
# 	volatility
# 	spectrogram
# 	intracellular
# 	cytometry
# 	chemicals
# 	resembling
# 	warranted
# 	reparametrizations
# 	plentiful
# 	isometric
# 	changepoints
# 	clinician
# 	offerings
# 	assortment
# 	depression
# 	depressive
# Some words which never appear in Statistics papers:
# 	connectionist
# 	personality
# 	unimportant
# 	liberated
# 	extraordinary
# 	morphable
# 	morphologically
# 	concatenation
# 	engineers
# 	synthesizer
# 	headlines
# 	animation
# 	enumerated
# 	enumerates
# 	administrators
# 	reranking
# 	grammatical
# 	institute
# 	disambiguate
# 	manipulators

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.067861087249969e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7566666666666667
